# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammadRehaanAli/Phishing-URL-Detector/blob/main/Level_1_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
black = pd.read_csv('/content/Blacklisted.csv')
white = pd.read_csv('/content/whitelisted.csv')
test_data = "https://google.com"
exists = white.applymap(lambda x: test_data in str(x)).any().any()
exists
# Out:
# <ipython-input-12-d8773d333106>:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   exists = white.applymap(lambda x: test_data in str(x)).any().any()
# True

# %%
white
# Out:
#               ID                                          Phish URL  \
# 0      8088092.0  https://urlscan.io/result/1db17b92-be69-4dc3-8...
# 1      8088008.0       https://www.google.com.py/search?q=csgoskins
# 2      8082169.0  https://bvnegocios.banrural.com.gt/corp/pages/...
# 3      8079397.0  https://login.microsoftonline.com.office.prod....
# 4      8079396.0  http://login.microsoftonline.com.office.prod.a...
# ...          ...                                                ...
# 60000  1906575.0               http://www.twoo.com/?mtid=47&login=1
# 60001  1906574.0  http://mail.twoo.com/mailurl/aT1nMC05ZjhqenUtN...
# 60002  1906476.0  http://thepiratebay.ee/torrent/6531051/WinAVI_...
# 60003  1906475.0  http://thepiratebay.ee/search/WinAVI%20Video%2...
# 60004  1906474.0        https://squareup.com/r/kawm5hnd6zyibz4v82_q
#
#            Submitted   Valid?  Online?
# 0          by shinya  INVALID  Offline
# 1       by Felix0101  INVALID  Offline
# ...
